# %%
# !pip install diffusers
# !pip install transformers
# !pip install pyngrok
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 31.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 50.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 90.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.2/681.2 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-6.0.0-py3-none-any.whl size=19867 sha256=2cc9cc67a697130b0c1fa0dcc1bc7a3dbd4683f87ea4a7531ba40c5c98e75d8a
#   Stored in directory: /root/.cache/pip/wheels/5c/42/78/0c3d438d7f5730451a25f7ac6cbf4391759d22a67576ed7c2c
# Successfully built pyngrok
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# !pip install flask_ngrok  # So we can make flask app port thru ngrok
# !pip install pyngrok==4.1.1  # To register our ngrok token
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15963 sha256=e24b8070d199fcab70bf00a7b8c36675aa21df9e3055501ab0f3eac75d3925f3
#   Stored in directory: /root/.cache/pip/wheels/4c/7c/4c/632fba2ea8e88d8890102eb07bc922e1ca8fa14db5902c91a8
# Successfully built pyngrok
# ...
#   Attempting uninstall: pyngrok
#     Found existing installation: pyngrok 6.0.0
#     Uninstalling pyngrok-6.0.0:
#       Successfully uninstalled pyngrok-6.0.0
# ...

# %%
# !ngrok authtoken RnrFcClw2K6aS9YwEm4k61N4As_6iRu3msgjc66WA5WBRfHE

# Take new ngrok token from ngrok website dashboard .
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from flask_ngrok import run_with_ngrok
# from flask import Flask, render_template, send_file, request
from flask import Flask, request, send_file
from diffusers import StableDiffusionPipeline
import torch
from pyngrok import ngrok
import io
app = Flask(__name__)
run_with_ngrok(app)

# Load the diffusion model
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to("cuda")

@app.route('/')
def initial():
  return "helloe word"

@app.route('/generate_images', methods=['POST'])
def generate_images():
    # Get the prompt from the request body
    prompt = request.json['prompt']

    # Generate the image using the diffusion model
    image = pipe(prompt).images[0]

    # Save the generated image to a BytesIO object
    image_bytes = io.BytesIO()
    image.save(image_bytes, format='PNG')
    image_bytes.seek(0)

    # Return the generated image as a file download
    return send_file(image_bytes, mimetype='image/png')

app.run()
# Out:
# ...
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# ...
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://ce57-34-123-148-39.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2023 08:34:18] "GET / HTTP/1.1" 200 -
# Token indices sequence length is longer than the specified maximum sequence length for this model (86 > 77). Running this sequence through the model will result in indexing errors
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['\' s first law of motion!! "']
# ...

# %%
# Sometimes don't work on some machine so recommended to use upper block of code it's work fine .
'''
from flask import Flask, request, send_file
from diffusers import StableDiffusionPipeline
import torch
from pyngrok import ngrok
import io

# Initialize Flask app
app = Flask(__name__)

# Load the diffusion model
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to("cuda")

@app.route('/heelo', methods=['POST'])
def hello():
    return "hello"


# Define the API endpoint for generating ihttps://www.thunderclient.com/welcomemages
@app.route('/generate_images', methods=['POST'])
def generate_images():
    # Get the prompt from the request body
    prompt = request.json['prompt']

    # Generate the image using the diffusion model
    image = pipe(prompt).images[0]

    # Save the generated image to a BytesIO object
    image_bytes = io.BytesIO()
    image.save(image_bytes, format='PNG')
    image_bytes.seek(0)

    # Return the generated image as a file download
    return send_file(image_bytes, mimetype='image/png')

# Run the Flask app using ngrok to expose endpoints
if __name__ == '__main__':
    # Start ngrok tunnel
    ngrok_tunnel = ngrok.connect(5000)
    print('Public URL:', ngrok_tunnel.public_url)

    # Run the Flask app
    app.run()

'''
# Out:
# ...
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.10/dist-packages/tqdm/contrib/concurrent.py:51 in _executor_map           │
# │                                                                                                  │
# │    48 │   │   # share lock in case workers are already using `tqdm`                              │
# │    49 │   │   with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,        │
# │    50 │   │   │   │   │   │     initargs=(lk,)) as ex:                                           │
# │ ❱  51 │   │   │   return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs   │
# │    52                                                                                            │
# │    53                                                                                            │
# ...
